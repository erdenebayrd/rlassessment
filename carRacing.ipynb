# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
# creating an env of the CarRacing game
env = gym.make("CarRacing-v3")

# %%
# Wrap with DummyVecEnv for Stable Baselines3
vec_env = DummyVecEnv([lambda: env])

# %%
# Create model
model = PPO("CnnPolicy", vec_env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
# Train for some timesteps
model.learn(total_timesteps=100000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 191  |
# |    iterations      | 1    |
# |    time_elapsed    | 10   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 2           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007076878 |
# |    clip_fraction        | 0.0882      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.00286     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.178       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00942    |
# |    std                  | 0.984       |
# |    value_loss           | 0.611       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 3           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009652412 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0915      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00767    |
# |    std                  | 0.984       |
# |    value_loss           | 0.533       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 4           |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010416197 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.452       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0686      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.974       |
# |    value_loss           | 0.441       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 5           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011908997 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.957       |
# |    value_loss           | 0.37        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 6           |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011409871 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | -0.0828     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.102       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00898    |
# |    std                  | 0.958       |
# |    value_loss           | 0.345       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 7           |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013451301 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0256      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.947       |
# |    value_loss           | 0.281       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 82        |
# |    iterations           | 8         |
# |    time_elapsed         | 197       |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0128693 |
# |    clip_fraction        | 0.139     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.08     |
# |    explained_variance   | 0.669     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.12      |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -0.0143   |
# |    std                  | 0.939     |
# |    value_loss           | 0.319     |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 9           |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.016206365 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00214    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0211     |
# |    std                  | 0.927       |
# |    value_loss           | 0.243       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 80         |
# |    iterations           | 10         |
# |    time_elapsed         | 254        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01686677 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.02      |
# |    explained_variance   | 0.766      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.066      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0137    |
# |    std                  | 0.922      |
# |    value_loss           | 0.281      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 11          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.019874165 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00263     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0258     |
# |    std                  | 0.914       |
# |    value_loss           | 0.231       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 12          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.027997267 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0113     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.906       |
# |    value_loss           | 0.2         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 13          |
# |    time_elapsed         | 343         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.020466648 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.082       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0251     |
# |    std                  | 0.892       |
# |    value_loss           | 0.257       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 14          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.020770522 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.88       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0555      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0206     |
# |    std                  | 0.872       |
# |    value_loss           | 0.405       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 15          |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020883115 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0782      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.86        |
# |    value_loss           | 0.42        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 16          |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.037189253 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0364      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0237     |
# |    std                  | 0.852       |
# |    value_loss           | 0.267       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 17          |
# |    time_elapsed         | 443         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.020250864 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.257       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.847       |
# |    value_loss           | 0.802       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 18         |
# |    time_elapsed         | 469        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02050239 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.75      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.168      |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0175    |
# |    std                  | 0.842      |
# |    value_loss           | 0.645      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 19          |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.025163094 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.148       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.834       |
# |    value_loss           | 0.426       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 20          |
# |    time_elapsed         | 517         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.032552697 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00784     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0183     |
# |    std                  | 0.82        |
# |    value_loss           | 0.219       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 21          |
# |    time_elapsed         | 541         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.031347856 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0541      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.815       |
# |    value_loss           | 0.274       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 22          |
# |    time_elapsed         | 566         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.022859486 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0989      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0197     |
# |    std                  | 0.81        |
# |    value_loss           | 0.715       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 23          |
# |    time_elapsed         | 590         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.022812404 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.244       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 0.802       |
# |    value_loss           | 0.897       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 24         |
# |    time_elapsed         | 615        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.03396373 |
# |    clip_fraction        | 0.294      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.58      |
# |    explained_variance   | 0.67       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.417      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0245    |
# |    std                  | 0.798      |
# |    value_loss           | 1.9        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 25          |
# |    time_elapsed         | 639         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.025080577 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.678       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.791       |
# |    value_loss           | 1.83        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 80         |
# |    iterations           | 26         |
# |    time_elapsed         | 663        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.03018161 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.53      |
# |    explained_variance   | 0.894      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.238      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0104    |
# |    std                  | 0.788      |
# |    value_loss           | 1.54       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 80         |
# |    iterations           | 27         |
# |    time_elapsed         | 688        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.03750523 |
# |    clip_fraction        | 0.306      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.51      |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.193      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0191    |
# |    std                  | 0.78       |
# |    value_loss           | 1.59       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 28          |
# |    time_elapsed         | 712         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.029050358 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.259       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0209     |
# |    std                  | 0.776       |
# |    value_loss           | 1.93        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 80         |
# |    iterations           | 29         |
# |    time_elapsed         | 739        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.02717373 |
# |    clip_fraction        | 0.308      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.47      |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.219      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0102    |
# |    std                  | 0.771      |
# |    value_loss           | 1.38       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 30          |
# |    time_elapsed         | 764         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.036323767 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.657       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00578    |
# |    std                  | 0.769       |
# |    value_loss           | 3.56        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 31          |
# |    time_elapsed         | 789         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.030481711 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.532       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.768       |
# |    value_loss           | 3.22        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 32          |
# |    time_elapsed         | 815         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.043052197 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00722    |
# |    std                  | 0.767       |
# |    value_loss           | 3.14        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 33          |
# |    time_elapsed         | 840         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.044832215 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.407       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.76        |
# |    value_loss           | 2.53        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 80         |
# |    iterations           | 34         |
# |    time_elapsed         | 866        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.04214178 |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.4       |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.414      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0126    |
# |    std                  | 0.756      |
# |    value_loss           | 2.95       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 35          |
# |    time_elapsed         | 890         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.049921945 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.305       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00654    |
# |    std                  | 0.752       |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 36          |
# |    time_elapsed         | 914         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.059208073 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.37       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.603       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.000602    |
# |    std                  | 0.749       |
# |    value_loss           | 5.16        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 80         |
# |    iterations           | 37         |
# |    time_elapsed         | 939        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.21115431 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | 0.868      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.41       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0103    |
# |    std                  | 0.746      |
# |    value_loss           | 8.52       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 38          |
# |    time_elapsed         | 963         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.056870677 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0014     |
# |    std                  | 0.746       |
# |    value_loss           | 5.5         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 80         |
# |    iterations           | 39         |
# |    time_elapsed         | 987        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.03570646 |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.33      |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.26       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.00248    |
# |    std                  | 0.741      |
# |    value_loss           | 4.25       |
# ----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 80       |
# |    iterations           | 40       |
# |    time_elapsed         | 1011     |
# |    total_timesteps      | 81920    |
# | train/                  |          |
# |    approx_kl            | 0.072697 |
# |    clip_fraction        | 0.4      |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3.31    |
# |    explained_variance   | 0.939    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.909    |
# |    n_updates            | 390      |
# |    policy_gradient_loss | -0.00717 |
# |    std                  | 0.736    |
# |    value_loss           | 5.85     |
# --------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 41         |
# |    time_elapsed         | 1035       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.03698197 |
# |    clip_fraction        | 0.396      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.29      |
# |    explained_variance   | 0.929      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.15       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.000618   |
# |    std                  | 0.732      |
# |    value_loss           | 5.93       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 42         |
# |    time_elapsed         | 1061       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.04065175 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.27      |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.665      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.000132  |
# |    std                  | 0.728      |
# |    value_loss           | 5.49       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 43         |
# |    time_elapsed         | 1085       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.23230407 |
# |    clip_fraction        | 0.5        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.26      |
# |    explained_variance   | 0.785      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.72       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.00712    |
# |    std                  | 0.724      |
# |    value_loss           | 20.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 44         |
# |    time_elapsed         | 1110       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.07167567 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.25      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.347      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.0122     |
# |    std                  | 0.724      |
# |    value_loss           | 3.76       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 45          |
# |    time_elapsed         | 1134        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.071805865 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.585       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0137      |
# |    std                  | 0.716       |
# |    value_loss           | 5.29        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 46         |
# |    time_elapsed         | 1158       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.07006652 |
# |    clip_fraction        | 0.44       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.625      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.00982    |
# |    std                  | 0.718      |
# |    value_loss           | 3.83       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 47         |
# |    time_elapsed         | 1184       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.17775065 |
# |    clip_fraction        | 0.475      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.23      |
# |    explained_variance   | 0.862      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.36       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.00791    |
# |    std                  | 0.717      |
# |    value_loss           | 15.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 48         |
# |    time_elapsed         | 1210       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.07816568 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.818      |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.000124   |
# |    std                  | 0.713      |
# |    value_loss           | 7.75       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 49         |
# |    time_elapsed         | 1234       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.07345564 |
# |    clip_fraction        | 0.378      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.938      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.776      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.0106     |
# |    std                  | 0.71       |
# |    value_loss           | 9.23       |
# ----------------------------------------

# %%
# Save the model
model.save("./ppo_carracing")

# %%
# Load trained model
model = PPO.load("./ppo_carracing.zip")

# Create CarRacing environment (with or without render_mode="human")
env = gym.make("CarRacing-v3", render_mode="human")

# %%
# Number of episodes to evaluate
num_episodes = 50
episode_rewards = []
